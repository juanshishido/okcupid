# %% [markdown]
# This notebook sets up the workflow for the various functions we have implemented. It shows an example of how we clustered using Nonnegative Matrix Factorization. We manually inspect the output of NMF to determine the best number of clusters for each group

# %%
import pickle
import warnings

from utils.hash import make
from utils.calculate_pmi_features import *
from utils.clean_up import *
from utils.categorize_demographics import *
from utils.reduce_dimensions import run_kmeans
from utils.nonnegative_matrix_factorization import nmf_inspect, nmf_labels
warnings.filterwarnings('ignore')

# %% [markdown]
# Getting the data, cleaning it, and categorizing demographic data

# %%
df = get_data()

# %%
essay_list = ['essay0','essay4','essay5']
df_clean = clean_up(df, essay_list)

# %%
df_clean.fillna('', inplace=True)

# %%
df.columns.values
# Out:
# array(['username', 'age', 'body_type', 'diet', 'drinks', 'drugs',
#        'education', 'essay0', 'essay1', 'essay2', 'essay3', 'essay4',
#        'essay5', 'essay6', 'essay7', 'essay8', 'essay9', 'ethnicity',
#        'height', 'income', 'job', 'last_online', 'location', 'offspring',
#        'orientation', 'pets', 'religion', 'sex', 'sign', 'smokes',
#        'speaks', 'status', 'TotalEssays'], dtype=object)

# %%
df_clean['religion'] = df_clean['religion'].apply(religion_categories)
df_clean['job'] = df_clean['job'].apply(job_categories)
df_clean['drugs'] = df_clean['drugs'].apply(drug_categories)
df_clean['diet'] = df_clean['diet'].apply(diet_categories)
df_clean['body_type'] = df_clean['body_type'].apply(body_categories)
df_clean['drinks'] = df_clean['drinks'].apply(drink_categories)
df_clean['sign'] = df_clean['sign'].apply(sign_categories)
df_clean['ethnicity'] = df_clean['ethnicity'].apply(ethnicity_categories)
df_clean['pets'] = df_clean['pets'].apply(pets_categories)
df_clean['speaks'] = df_clean['speaks'].apply(language_categories)

# %% [markdown]
# Splitting the dataframe by gender, running clustering separately on each.

# %%
df_male = df_clean[df_clean['sex'] == 'm']

# %%
df_female = df_clean[df_clean['sex'] == 'f']

# %%
count_matrix_m, tfidf_matrix_m, vocab_m = col_to_data_matrix(df_male, 'essay0') #save out

# %%
count_matrix_f, tfidf_matrix_f, vocab_f = col_to_data_matrix(df_female, 'essay0')

# %%
vocab_m
# Out:
# {'friends': 625,
#  'europe': 563,
#  'focus': 605,
#  'artistic': 315,
#  ', easy': 50,
#  'earth': 534,
#  'animals': 305,
#  'sure': 1317,
#  'starting': 1292,
#  'outside': 1068,
#  ', enjoy': 52,
#  'cold': 425,
#  ". i'm pretty": 191,
#  'hiking': 733,
#  'ambitious': 302,
#  'stay': 1295,
#  'box': 372,
#  'makes': 944,
#  '8': 267,
#  'longer': 908,
#  'thought': 1356,
#  'highly': 731,
#  'restaurants ,': 1174,
#  'school': 1208,
#  'hands': 699,
#  ', say': 126,
#  'crazy': 464,
#  'enjoy going': 557,
#  'loyal ,': 938,
#  'knows': 843,
#  'known': 842,
#  ', cooking ,': 44,
#  'meet people': 961,
#  ', cooking': 43,
#  ', reading ,': 120,
#  'south': 1273,
#  ', movies ,': 103,
#  'doing .': 514,
#  'mission': 975,
#  'language': 847,
#  '!': 0,
#  '. really': 225,
#  'include': 795,
#  'traveling': 1375,
#  'rock climbing': 1183,
#  'optimistic': 1059,
#  'general': 644,
#  "'": 14,
#  'definitely': 496,
#  'graduate': 680,
#  'fullest': 630,
#  'cultures': 471,
#  'nights': 1031,
#  'sounds': 1272,
#  'yeah ,': 1489,
#  'situations': 1253,
#  'just moved': 826,
#  'laid ,': 846,
#  'kick': 830,
#  'recently': 1160,
#  'make': 941,
#  'proud': 1135,
#  ', long': 93,
#  'point': 1115,
#  'want know': 1425,
#  '! !': 1,
#  '! )': 3,
#  'family': 584,
#  'passions': 1080,
#  ', smart': 127,
#  'know': 838,
#  'activities': 285,
#  '. open': 218,
#  'lets': 868,
#  ':': 268,
#  'involved': 810,
#  'couple': 462,
#  '. think': 237,
#  'graduated': 681,
#  'hi': 727,
#  'girls': 654,
#  'family ,': 585,
#  'family .': 586,
#  'weekends': 1444,
#  '. right': 227,
#  'lead': 859,
#  ', doing': 48,
#  'term': 1338,
#  'grow': 685,
#  '. love travel': 209,
#  'drink': 525,
#  'years ago': 1496,
#  ', really': 121,
#  "say i'm": 1204,
#  ', exploring': 54,
#  'jokes': 819,
#  'keeps': 828,
#  'west': 1448,
#  'shit': 1237,
#  'having fun': 713,
#  'touch': 1368,
#  ', hanging': 68,
#  '. lived': 205,
#  'need': 1010,
#  'communication': 436,
#  'remember': 1169,
#  "haven't": 711,
#  ', try': 142,
#  'woman': 1462,
#  '. friends': 177,
#  "don't want": 520,
#  'sharing': 1236,
#  'grown': 687,
#  'times': 1362,
#  '. ?': 162,
#  '. "': 155,
#  '. -': 160,
#  '. ,': 158,
#  '. .': 161,
#  '. )': 157,
#  '. (': 156,
#  'style': 1310,
#  'photography ,': 1096,
#  'helping': 724,
#  'like people': 884,
#  ':)': 271,
#  'said': 1191,
#  'unless': 1403,
#  'driven': 529,
#  'parties': 1073,
#  ". let's": 201,
#  '. born': 166,
#  'chemistry': 407,
#  'deal': 491,
#  ', especially': 53,
#  'gym': 694,
#  'culture': 470,
#  'speak': 1276,
#  'seen': 1216,
#  'seek': 1214,
#  'politics': 1118,
#  'cause': 400,
#  'yes ,': 1500,
#  'damn': 480,
#  'months': 983,
#  'stuff .': 1309,
#  "( i'm": 18,
#  'uc': 1398,
#  'studied': 1305,
#  'meet .': 958,
#  'sort': 1269,
#  'fair': 581,
#  ', camping ,': 40,
#  ', travel': 138,
#  'god': 660,
#  'got': 677,
#  'eating': 544,
#  'new': 1014,
#  'nearly': 1009,
#  'trying new things': 1391,
#  'like .': 880,
#  'like ,': 879,
#  'leave': 864,
#  'drinking': 526,
#  'emotional': 547,
#  'working ,': 1475,
#  'just .': 823,
#  'street': 1301,
#  'hang': 700,
#  'hand': 698,
#  'shape': 1234,
#  '! love': 6,
#  'journey': 820,
#  'feeling': 596,
#  'average': 325,
#  'american': 304,
#  'particular': 1071,
#  'lot .': 917,
#  '. yes': 246,
#  'sf': 1231,
#  'intelligent ,': 804,
#  'month': 982,
#  'romantic': 1184,
#  'meeting': 962,
#  'appreciate': 307,
#  'amazing': 301,
#  'possible .': 1122,
#  '. read': 224,
#  ". i've lived": 194,
#  "i'm really": 782,
#  'casual': 397,
#  'tech': 1332,
#  'friendly ,': 624,
#  'dancing ,': 483,
#  "i'm interested": 774,
#  'women': 1463,
#  'new places': 1021,
#  'simple': 1244,
#  'near': 1008,
#  'child': 409,
#  'people ,': 1084,
#  'tell': 1334,
#  '. know': 200,
#  'trust': 1383,
#  'tennis': 1336,
#  ', music': 104,
#  ', running': 124,
#  'site': 1250,
#  'spend time': 1279,
#  'ones': 1052,
#  'questions': 1139,
#  'years ,': 1494,
#  'years .': 1495,
#  'mountains': 987,
#  'look': 909,
#  'takes': 1323,
#  'taken': 1322,
#  "i'm": 765,
#  "i'd": 761,
#  '. maybe': 211,
#  "i'm currently": 769,
#  'friendship': 629,
#  '. favorite': 175,
#  'san francisco': 1194,
#  '. grew': 182,
#  'afraid': 297,
#  '/': 253,
#  'camping': 386,
#  '. got': 180,
#  'online': 1053,
#  'lol': 905,
#  'lot': 915,
#  'love good': 925,
#  'big': 355,
#  '. usually': 242,
#  'business': 379,
#  ', .': 31,
#  ', ,': 30,
#  ', (': 29,
#  'board': 361,
#  'feel like': 595,
#  'figure': 598,
#  'usually': 1408,
#  'fall': 583,
#  "it's": 812,
#  'english': 554,
#  'genuine': 648,
#  'hate': 710,
#  "they're": 1343,
#  'basketball': 338,
#  'musician': 1003,
#  ". i've": 193,
#  'pretty': 1126,
#  'yes': 1499,
#  'gay': 641,
#  'thing ,': 1345,
#  'right ?': 1180,
#  'right ,': 1178,
#  'right .': 1179,
#  'personal': 1091,
#  ", i'm looking": 78,
#  'company .': 439,
#  'looking': 910,
#  'watch': 1429,
#  'described': 498,
#  'past': 1081,
#  "i'm sure": 783,
#  ". i'm big": 189,
#  '. just': 198,
#  'best': 351,
#  'better .': 354,
#  'late': 850,
#  'willing': 1454,
#  'needs': 1011,
#  'camping ,': 387,
#  'world .': 1479,
#  'world ,': 1478,
#  'climbing ,': 419,
#  'human': 756,
#  'sing': 1246,
#  'motorcycle': 985,
#  'music': 1000,
#  'reason': 1158,
#  '. good': 179,
#  'nice ,': 1028,
#  'drinks': 527,
#  'california': 382,
#  'piano': 1100,
#  "i'm just": 775,
#  'laid': 845,
#  'light': 877,
#  'update': 1404,
#  '. kind': 199,
#  'lost': 914,
#  'home ,': 740,
#  'golf': 665,
#  'internet': 809,
#  'love travel': 930,
#  "won't": 1464,
#  'stuff': 1308,
#  'berkeley': 350,
#  'quiet': 1141,
#  '.....': 252,
#  ', taking': 132,
#  'try new': 1387,
#  'expect': 571,
#  '. hope': 184,
#  'send': 1219,
#  'winter': 1457,
#  'want': 1423,
#  'admit': 289,
#  '. com': 168,
#  'www': 1486,
#  ', living': 92,
#  'restaurant': 1172,
#  'local': 904,
#  'watching': 1430,
#  'witty': 1460,
#  ', honest ,': 74,
#  'cute': 476,
#  'writer': 1483,
#  '? )': 277,
#  'build': 376,
#  "don't really": 518,
#  ', great': 67,
#  'took': 1366,
#  'used': 1406,
#  'wish': 1458,
#  'open minded': 1056,
#  ', traveling': 140,
#  'case': 396,
#  ", you're": 150,
#  'time ,': 1359,
#  'time .': 1360,
#  'single': 1248,
#  'body': 363,
#  "wouldn't": 1481,
#  ", i'd": 75,
#  ", i'm": 77,
#  'running ,': 1188,
#  ', working': 149,
#  'middle': 969,
#  ". don't": 172,
#  'stop': 1297,
#  'important': 793,
#  "i'm going": 771,
#  '. people': 219,
#  'common': 435,
#  ', loving': 96,
#  'parents': 1069,
#  'different': 505,
#  'new .': 1015,
#  'things': 1347,
#  'attracted': 323,
#  'happiness': 705,
#  "i've": 786,
#  'boring': 368,
#  ', right': 122,
#  'offer': 1042,
#  'dream': 523,
#  'yeah': 1488,
#  ', spontaneous': 130,
#  "don't": 515,
#  'drive': 528,
#  'games .': 640,
#  'games ,': 639,
#  'home': 739,
#  "i'm bit": 768,
#  'ocean': 1041,
#  'likely': 886,
#  'outdoors ,': 1064,
#  'outdoors .': 1065,
#  'adventure': 290,
#  'humor .': 760,
#  'eyes': 578,
#  'happen': 703,
#  ', live': 90,
#  'looking forward': 911,
#  'unique': 1401,
#  'people laugh': 1086,
#  'straight': 1300,
#  'political': 1117,
#  '. guess': 183,
#  'enjoys': 560,
#  'moved sf': 993,
#  'activity': 286,
#  'act': 282,
#  'gentleman': 647,
#  'follow': 606,
#  'honestly': 744,
#  'happens': 704,
#  'thoughtful': 1357,
#  'black': 360,
#  '%': 12,
#  'occasionally': 1040,
#  'father': 591,
#  "i'm kind": 776,
#  'time friends': 1361,
#  'adventure .': 291,
#  'number': 1036,
#  'loving ,': 935,
#  'catch': 398,
#  'caring': 393,
#  'matter': 952,
#  '. went': 244,
#  ". can't": 167,
#  'spent': 1282,
#  ', getting': 64,
#  'friends family': 628,
#  ', travel ,': 139,
#  'creative ,': 468,
#  ', smart ,': 128,
#  'works': 1476,
#  'meet new people': 960,
#  "life . i'm": 874,
#  'dinner': 507,
#  'rarely': 1146,
#  ', swimming': 131,
#  'comedy': 431,
#  'red': 1162,
#  'music .': 1002,
#  'music ,': 1001,
#  'happy ,': 707,
#  'happy .': 708,
#  'glass': 657,
#  "i'd love": 763,
#  'fit': 604,
#  'lot time': 918,
#  '..': 248,
#  'enjoy .': 556,
#  'especially': 562,
#  'family friends': 587,
#  'joy': 821,
#  'job': 815,
#  '. love': 208,
#  'good time': 674,
#  'relationship': 1164,
#  'living': 901,
#  'like': 878,
#  'long term': 907,
#  ', new': 107,
#  'area ,': 309,
#  'area .': 310,
#  "i'm .": 766,
#  'day .': 489,
#  'come': 430,
#  ', watching': 146,
#  'connection': 448,
#  'play': 1110,
#  'plan': 1108,
#  'club': 421,
#  'value': 1410,
#  'plus': 1114,
#  'group': 684,
#  'years old': 1498,
#  'bike': 356,
#  ')': 19,
#  'spending': 1280,
#  'second': 1212,
#  'growing': 686,
#  'sense humor ,': 1222,
#  "i'm big": 767,
#  'good food': 670,
#  'party': 1076,
#  'parts': 1075,
#  '- -': 152,
#  'goes': 661,
#  'situation': 1252,
#  'raised': 1144,
#  'add': 288,
#  'fine': 602,
#  'york': 1503,
#  'listening': 892,
#  'meeting new people': 964,
#  'adventurous': 294,
#  'getting know': 651,
#  'teach': 1329,
#  'travel .': 1373,
#  'work': 1469,
#  'word': 1467,
#  'weird': 1445,
#  'attractive': 324,
#  'room': 1185,
#  'later': 852,
#  '. said ,': 229,
#  'love music': 928,
#  'year': 1490,
#  'picture': 1101,
#  'care .': 391,
#  'kids': 832,
#  'smile': 1260,
#  ". , i'm": 159,
#  ', read': 118,
#  'seriously ,': 1226,
#  'hobbies': 737,
#  'geeky': 643,
#  'strive': 1302,
#  'playing': 1113,
#  'positive': 1120,
#  'traveling ,': 1376,
#  'soon': 1267,
#  'break': 374,
#  'worked': 1473,
#  'things like': 1351,
#  "isn't": 811,
#  'creativity': 469,
#  'absolutely': 281,
#  ', know': 85,
#  'creating': 466,
#  'values': 1411,
#  'fun .': 633,
#  'fun ,': 632,
#  'industry': 799,
#  'hair': 696,
#  'kind ,': 834,
#  'mix': 976,
#  'bay area': 341,
#  'realize': 1153,
#  'san francisco .': 1196,
#  'san francisco ,': 1195,
#  'university': 1402,
#  'books ,': 366,
#  'inside': 800,
#  "i'd like": 762,
#  ', passionate': 111,
#  'good sense humor': 673,
#  'study': 1306,
#  'mind': 971,
#  'northern': 1034,
#  'away': 326,
#  'professional': 1131,
#  ', family': 55,
#  'nice guy': 1029,
#  'photography': 1095,
#  'let': 866,
#  'times ,': 1363,
#  'times .': 1364,
#  'dude': 532,
#  'food ,': 608,
#  'ok': 1046,
#  'oh': 1044,
#  'suppose': 1316,
#  'seriously': 1225,
#  'heart': 718,
#  "i've lived": 788,
#  'goal': 658,
#  'moved bay area': 990,
#  'relax': 1167,
#  'comes': 432,
#  'cooking': 457,
#  '. lot': 207,
#  'loved': 931,
#  'loves': 933,
#  'athletic': 320,
#  'technology': 1333,
#  'feels': 597,
#  'boy': 373,
#  'spending time': 1281,
#  'answer': 306,
#  'generally': 645,
#  'learning': 862,
#  ', time': 137,
#  'practice': 1123,
#  '. oh': 216,
#  'guys': 693,
#  'curious': 472,
#  ', dancing': 47,
#  'future': 636,
#  'shy ,': 1241,
#  'outdoors': 1063,
#  'awkward': 329,
#  'west coast': 1449,
#  ':/': 272,
#  '. make': 210,
#  'sports .': 1288,
#  'summary': 1312,
#  'cycling': 477,
#  '-': 151,
#  'good conversation': 669,
#  ', just': 83,
#  ', food': 57,
#  ", it's": 82,
#  ', sarcastic': 125,
#  ", i'll": 76,
#  'beauty': 347,
#  'town': 1369,
#  'note': 1035,
#  'area': 308,
#  'biking': 357,
#  'relationships': 1166,
#  ', pretty': 116,
#  'honesty': 745,
#  'comfortable': 433,
#  'list': 889,
#  'great': 682,
#  "i'm good": 772,
#  'photos': 1097,
#  ', creative': 45,
#  'white': 1451,
#  'snowboarding': 1261,
#  'food': 607,
#  'head': 714,
#  'hear': 717,
#  "don't like": 517,
#  'week .': 1442,
#  'really enjoy': 1156,
#  'kind guy': 835,
#  'japan': 813,
#  'new restaurants': 1022,
#  'seeking': 1215,
#  'hope': 746,
#  'intelligent': 803,
#  'energy': 551,
#  'rest': 1171,
#  "here's": 725,
#  'beach ,': 345,
#  'theater': 1341,
#  'im': 792,
#  "you'll": 1505,
#  'sensitive': 1224,
#  'active ,': 284,
#  'try new things': 1388,
#  'message': 966,
#  'loyal': 937,
#  'biking ,': 358,
#  'despite': 502,
#  'opportunity': 1058,
#  'kid': 831,
#  'listen': 890,
#  '. used': 241,
#  ', making': 99,
#  'college .': 427,
#  'mountain': 986,
#  'busy': 380,
#  'beautiful': 346,
#  'using': 1407,
#  'favorite': 592,
#  'com': 428,
#  'humble': 757,
#  '1': 254,
#  'bay area ,': 342,
#  'bay area .': 343,
#  'long': 906,
#  'able': 279,
#  'ass': 319,
#  'ask': 317,
#  'confident': 447,
#  'dog': 511,
#  ", don't": 49,
#  ', adventurous': 33,
#  'creative': 467,
#  'work hard': 1472,
#  'city .': 415,
#  'city ,': 414,
#  "think i'm": 1354,
#  'read ,': 1148,
#  'young': 1508,
#  'relaxing': 1168,
#  'way ,': 1434,
#  'way .': 1435,
#  'high': 729,
#  '. try': 240,
#  'building': 377,
#  'moved bay': 989,
#  'moment': 978,
#  ', friends': 59,
#  'successful': 1311,
#  'try .': 1386,
#  'say': 1201,
#  'feel free': 594,
#  'laughing': 856,
#  'match': 951,
#  'active': 283,
#  'love going': 924,
#  'change': 404,
#  'giants': 652,
#  'football': 611,
#  'philosophy': 1094,
#  'park': 1070,
#  'character': 405,
#  'easy going ,': 541,
#  'given': 655,
#  'help': 723,
#  'hell': 721,
#  'education': 546,
#  'yoga ,': 1502,
#  'ask .': 318,
#  '. like': 203,
#  'politics ,': 1119,
#  '. consider': 170,
#  'outgoing': 1066,
#  'far': 589,
#  'fan': 588,
#  "... i'm": 250,
#  ', moved': 101,
#  'seeing': 1213,
#  '3': 260,
#  'men': 965,
#  'met': 967,
#  'treat': 1377,
#  'riding': 1176,
#  'wrong': 1485,
#  'restaurants': 1173,
#  'bored': 367,
#  'love laugh': 926,
#  'money': 981,
#  'bring': 375,
#  'nature': 1006,
#  'dreams': 524,
#  'east bay': 537,
#  ': "': 269,
#  'fresh': 620,
#  'likes': 887,
#  '. looking': 206,
#  'ready': 1151,
#  'beer': 348,
#  '. prefer': 221,
#  'teaching': 1331,
#  ', think': 136,
#  'sense': 1220,
#  'learned': 861,
#  'skills': 1255,
#  'caring ,': 394,
#  '. want': 243,
#  'simply': 1245,
#  'understanding': 1400,
#  'road': 1181,
#  ', lived': 91,
#  'love .': 923,
#  'living san francisco': 903,
#  'face': 579,
#  'fact': 580,
#  'taking': 1324,
#  'make people': 943,
#  "that's": 1340,
#  'sex': 1229,
#  'set': 1228,
#  'san': 1193,
#  'tend': 1335,
#  'dogs': 512,
#  '5': 263,
#  'california .': 383,
#  'run': 1186,
#  'easily': 535,
#  'clubs': 422,
#  'sports': 1286,
#  'walks': 1422,
#  'honest': 742,
#  'create': 465,
#  "i'll": 764,
#  'life': 871,
#  'smart ,': 1259,
#  'live': 895,
#  'geek': 642,
#  ". i'd like": 186,
#  ', funny': 62,
#  ") i'm": 23,
#  'quirky': 1142,
#  'somewhat': 1266,
#  'ice': 789,
#  '...': 249,
#  '. things': 236,
#  ', learning': 86,
#  "i'm passionate": 780,
#  ', creative ,': 46,
#  'awesome .': 328,
#  'important .': 794,
#  "we're": 1438,
#  'man': 947,
#  'museums': 999,
#  "you're": 1506,
#  'dark': 484,
#  'hot': 749,
#  'boston': 371,
#  '. feel': 176,
#  ". it's": 197,
#  'date': 485,
#  'early': 533,
#  'making': 945,
#  'spontaneous': 1285,
#  ") . i'm": 22,
#  'u': 1397,
#  'decent': 492,
#  'independent': 797,
#  'funny': 634,
#  'lived': 899,
#  'hold': 738,
#  'house': 751,
#  "let's": 867,
#  'lifestyle': 876,
#  'state': 1293,
#  'perspective': 1093,
#  'love': 921,
#  'north': 1033,
#  'foods': 610,
#  'getting': 650,
#  '. play': 220,
#  '. fun': 178,
#  'movies .': 997,
#  '. interested': 196,
#  'equally': 561,
#  'days': 490,
#  'hello': 722,
#  ', honest': 73,
#  'keeping': 827,
#  'new people': 1018,
#  "i'm originally": 779,
#  '7': 266,
#  'guy ,': 691,
#  'dive': 508,
#  'scene': 1207,
#  'true': 1381,
#  'desire': 501,
#  'wild': 1453,
#  "i'm pretty": 781,
#  'moved': 988,
#  'hopefully': 747,
#  'short': 1238,
#  'age': 298,
#  'ago': 299,
#  'mean': 955,
#  'physically': 1099,
#  'moving': 998,
#  ', love': 95,
#  ', fun': 60,
#  'problem': 1129,
#  'love ,': 922,
#  'key': 829,
#  'places ,': 1106,
#  'love life': 927,
#  'originally': 1061,
#  'quite': 1143,
#  'played': 1111,
#  'visit': 1418,
#  'typical': 1396,
#  'similar': 1243,
#  'lot ,': 916,
#  'fast': 590,
#  'worth': 1480,
#  'sun': 1314,
#  'mind .': 972,
#  'dating': 486,
#  'thing .': 1346,
#  "life's": 875,
#  'witty ,': 1461,
#  'interests': 808,
#  'minded': 973,
#  '. currently': 171,
#  'okcupid': 1050,
#  'french': 619,
#  'write': 1482,
#  ', looking': 94,
#  'home .': 741,
#  ', make': 98,
#  'ago .': 300,
#  'understand': 1399,
#  ';': 274,
#  ', going': 65,
#  '10 years': 256,
#  'read': 1147,
#  'real': 1152,
#  'spend': 1278,
#  'fun': 631,
#  "who's": 1452,
#  '! ! !': 2,
#  'playful': 1112,
#  'deeply': 495,
#  '. enjoy': 173,
#  'snowboarding ,': 1262,
#  'adventures': 292,
#  'certain': 401,
#  'sorry': 1268,
#  'present': 1125,
#  's': 1189,
#  'recently moved': 1161,
#  'hanging friends': 702,
#  'instead': 801,
#  'probably': 1128,
#  '&': 13,
#  'wonderful': 1466,
#  'career': 392,
#  'languages': 848,
#  ". you're": 247,
#  ', fun ,': 61,
#  'eventually': 565,
#  "you've": 1507,
#  'reading': 1149,
#  'health': 715,
#  'explore': 575,
#  '. time': 238,
#  'tv': 1393,
#  'make laugh': 942,
#  'like think': 885,
#  '. big': 165,
#  'types': 1395,
#  'sit': 1249,
#  'try': 1385,
#  'various': 1413,
#  'came': 385,
#  'living san': 902,
#  's .': 1190,
#  'lately': 851,
#  'haha': 695,
#  "you'd": 1504,
#  'say ,': 1202,
#  'share': 1235,
#  'exactly': 567,
#  'attention': 321,
#  'public': 1136,
#  'book': 364,
#  'tried': 1378,
#  "didn't": 504,
#  "? i'm": 278,
#  'lucky': 939,
#  'trying': 1389,
#  'nerd': 1012,
#  "i'm happy": 773,
#  ', like': 88,
#  ', people': 112,
#  'bay .': 340,
#  'good ,': 667,
#  "' s": 15,
#  ', intelligent ,': 81,
#  'excited': 568,
#  'nature ,': 1007,
#  'sense humor': 1221,
#  'old': 1051,
#  'normal': 1032,
#  'new experiences': 1016,
#  'warm': 1428,
#  'constantly': 450,
#  'traveled': 1374,
#  'liberal': 870,
#  'surfing': 1318,
#  'sf .': 1233,
#  '. probably': 223,
#  'good friends': 671,
#  'space': 1275,
#  'free time': 618,
#  '20': 259,
#  'view': 1417,
#  '. tend': 233,
#  'staying': 1296,
#  'moved san': 991,
#  'profile .': 1133,
#  ', music ,': 105,
#  'valley': 1409,
#  ', trying': 143,
#  '?': 276,
#  'games': 638,
#  'just like': 824,
#  'nerdy': 1013,
#  'degree': 497,
#  'sitting': 1251,
#  ', funny ,': 63,
#  'super': 1315,
#  ', hiking': 71,
#  'night': 1030,
#  'climbing': 418,
#  'difficult': 506,
#  'engineer': 552,
#  'ca': 381,
#  'open': 1055,
#  'community': 437,
#  'means': 956,
#  'high school': 730,
#  'went school': 1447,
#  'half': 697,
#  'backpacking': 330,
#  'question': 1138,
#  ', need': 106,
#  'chance': 403,
#  'think': 1352,
#  'said ,': 1192,
#  'smart': 1258,
#  'personality': 1092,
#  ';)': 275,
#  'oakland': 1038,
#  'really .': 1155,
#  '. spend': 231,
#  '. spent': 232,
#  'cooking ,': 458,
#  'class': 416,
#  'com /': 429,
#  'really': 1154,
#  'better': 353,
#  'ok ,': 1047,
#  'adventures .': 293,
#  '. travel': 239,
#  "can't": 388,
#  ', playing': 115,
#  'sf ,': 1232,
#  'software': 1265,
#  ', reading': 119,
#  'laugh': 853,
#  'silly': 1242,
#  'francisco ,': 615,
#  'francisco .': 616,
#  'coffee': 424,
#  ', believe': 36,
#  ...}

# %%
nmf_inspect(tfidf_matrix_m, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-ae43deda7c85> in <module>()
# ----> 1 nmf_inspect(tfidf_matrix_m)
#
# TypeError: nmf_inspect() missing 1 required positional argument: 'feature_names'

# %%
nmf_inspect(tfidf_matrix_f)
